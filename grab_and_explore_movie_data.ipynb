# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 1: Read in the Data
#
# Data is being read in from [learn-co-students](https://github.com/learn-co-students/dc_ds_06_03_19/tree/master/module_1/week_3_project/data)
#
# Each dataframe is named after its filename (with underscores instead of '.') and followed by 'df'.
# The following cell usually shows .head(), but will/should be simple big pictures of what is in the file.
#
# ***

# %%
bom_movie_gross_df = pd.read_csv('data/bom.movie_gross.csv.gz')

# %%
bom_movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
tn_movie_budgets_df = pd.read_csv('data/tn.movie_budgets.csv.gz')

# %%
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
imdb_name_basics_df = pd.read_csv('data/imdb.name.basics.csv.gz')

# %%
imdb_name_basics_df.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdb_title_akas_df = pd.read_csv('data/imdb.title.akas.csv.gz')

# %%
# imdb_title_akas_df.head()
imdb_title_akas_df.sort_values('is_original_title', ascending=False).groupby('title_id').first()
# Out:
#            ordering                                              title region  \
# title_id
# tt0063540         2                                          Sunghursh     IN
# tt0066787         4                                    Ashad Ka Ek Din     IN
# tt0069049         8                         The Other Side of the Wind     GB
# tt0069204         3                                    Sabse Bada Sukh     IN
# tt0100275         1                              La Telenovela Errante     PL
# tt0111414         1                                        A Thin Life     AU
# tt0112502         1                                            Bigfoot     US
# tt0137204         3                                    Joe Finds Grace     CA
# tt0139613         1                                         O Silêncio     PT
# tt0144449         1                              Nema aviona za Zagreb     NL
# tt0146592         6                                        Pál Adrienn     SE
# tt0154039         1                                     Oda az igazság     PL
# tt0159369         1                 Cooper and Hemingway: The True Gen     US
# tt0162942         3                           A zöld sárkány gyermekei    XWW
# tt0176694         3                                Az ember tragédiája    XWW
# tt0187902         1  How Huang Fei-hong Rescued the Orphan from the...     HK
# tt0192528         2                                     Reverse Heaven     US
# tt0230212         1                                  The Final Journey     US
# tt0247643         1                   Los pájaros se van con la muerte     VE
# tt0249516         6                                         Foodfight!     LT
# tt0250404         1                                          Godfather     PK
# tt0253093         1                                       Gangavataran     IN
# tt0255820         2                                  Return to Babylon     RU
# tt0262218         2                                  Akakis mogzauroba     RU
# tt0262759         2                        Siedmiu Zydów z mojej klasy    XWW
# tt0263814         1                                           On kadin     TR
# tt0276568         1                                 To Chase a Million     GB
# tt0277964         3                      Praha - neklidné srdce Evropy     IT
# tt0283440         3                                     Kurzzeithelden    XWW
# tt0285252         5                                     Life's a Beach     CA
# ...             ...                                                ...    ...
# tt9887134         3                    La cuenca de los ríos de piedra    XWW
# tt9887290         1                                        Tsip Choelo    XWW
# tt9888844         1                          Vosotros sois mi película     ES
# tt9890060         1                      Maguy Marin: L'urgence d'agir     FR
# tt9890430         3                     The Secret of Carlos Castaneda     LT
# tt9890758         2  Gekijôban Urutoraman Rûbu Serekuto! Kizuna no ...    XWW
# tt9891764         2                                  Empire of Mirrors     FR
# tt9891934         2                                 My Name is Khadija     DE
# tt9892716         2             The King of Paparazzi - La vera storia     IT
# tt9894012         3                                         Pokemon XY     KR
# tt9894394         1                 Upin & Ipin: Keris Siamang Tunggal     VN
# tt9897528         2                                            Be Kind     IT
# tt9897744         1                              Duga, les charognards    XWW
# tt9899716         1       Star Trek Enterprise II: Der Anfang vom Ende    XWW
# tt9899840         3                                  Khaleh Ghurbagheh    XWW
# tt9899850         1                                          Ashoftegi     IR
# tt9899860         2                             Didan in film jorm ast    XWW
# tt9899880         1                                           Columbus     IR
# tt9899938         3                                Kibaiyanse! Watashi    XWW
# tt9900060         2                Lupin the IIIrd: Mine Fujiko no Uso    XWW
# tt9900688         3                                        Da San Yuan    XWW
# tt9903952         3                        BADMEN with a good behavior     DE
# tt9905462         1                                          Pengalila     IN
# tt9911006         2                                              Ormma     IN
# tt9911306         1                                     Kalikkoottukar     IN
# tt9911774         1                          Padmavyuhathile Abhimanyu     IN
# tt9913248         1                                   Nepal - Homebird     AT
# tt9914254         1                                  Kirsebæreventyret    XWW
# tt9915436         2                                  Vida em Movimento     US
# tt9916170         3                                           O Ensaio     BR
#
#           language     types                  attributes  is_original_title
# title_id
# tt0063540       hi  original        alternative spelling                1.0
# tt0066787       en  original                         NaN                1.0
# tt0069049      NaN  original                         NaN                1.0
# tt0069204       en  original                         NaN                1.0
# tt0100275       en  original  informal alternative title                1.0
# tt0111414      NaN       NaN                         NaN                0.0
# tt0112502      NaN       NaN                         NaN                0.0
# tt0137204      NaN  original                         NaN                1.0
# tt0139613      NaN       NaN                         NaN                0.0
# tt0144449      NaN       NaN                         NaN                0.0
# tt0146592       bg  original                         NaN                1.0
# tt0154039       en  original                         NaN                1.0
# tt0159369      NaN  original                         NaN                1.0
# tt0162942       en  original                         NaN                1.0
# tt0176694       en  original                         NaN                1.0
# tt0187902      NaN       NaN                         NaN                0.0
# tt0192528      NaN  original                         NaN                1.0
# tt0230212      NaN       NaN                         NaN                0.0
# tt0247643      NaN       NaN                         NaN                0.0
# tt0249516      NaN  original                         NaN                1.0
# tt0250404      NaN       NaN                         NaN                0.0
# tt0253093       en  original                         NaN                1.0
# tt0255820       en  original                         NaN                1.0
# tt0262218       en  original               literal title                1.0
# tt0262759       en  original                         NaN                1.0
# tt0263814      NaN       NaN                         NaN                0.0
# tt0276568      NaN       NaN                         NaN                0.0
# tt0277964       en  original                         NaN                1.0
# tt0283440       en  original                         NaN                1.0
# tt0285252       en  original                         NaN                1.0
# ...            ...       ...                         ...                ...
# tt9887134       en  original       literal English title                1.0
# tt9887290       en  original                         NaN                1.0
# tt9888844      NaN  original                         NaN                1.0
# tt9890060      NaN  original                         NaN                1.0
# tt9890430      NaN  original                         NaN                1.0
# tt9890758       en  original                         NaN                1.0
# tt9891764      NaN  original                         NaN                1.0
# tt9891934      NaN  original                         NaN                1.0
# tt9892716      NaN  original                         NaN                1.0
# tt9894012      NaN  original              complete title                1.0
# tt9894394       en  original                         NaN                1.0
# tt9897528      NaN  original                         NaN                1.0
# tt9897744       en  original      informal English title                1.0
# tt9899716       en  original                         NaN                1.0
# tt9899840       en  original                         NaN                1.0
# tt9899850       en  original                         NaN                1.0
# tt9899860       en  original                         NaN                1.0
# tt9899880       fa  original                         NaN                1.0
# tt9899938       en  original                         NaN                1.0
# tt9900060       en  original                         NaN                1.0
# tt9900688       en  original                         NaN                1.0
# tt9903952      NaN  original                         NaN                1.0
# tt9905462       en  original       literal English title                1.0
# tt9911006       ml  original        alternative spelling                1.0
# tt9911306       ml  original        alternative spelling                1.0
# tt9911774       ml  original        alternative spelling                1.0
# tt9913248      NaN  original                         NaN                1.0
# tt9914254       en  original                         NaN                1.0
# tt9915436      NaN  original                         NaN                1.0
# tt9916170       en  original                         NaN                1.0
#
# [122302 rows x 7 columns]

# %%
imdb_title_basics_df = pd.read_csv('data/imdb.title.basics.csv.gz')

# %%
imdb_title_basics_df.head(7)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy
# 6        2017              NaN       Horror,Thriller

# %%
imdb_title_crew_df = pd.read_csv('data/imdb.title.crew.csv.gz')

# %%
imdb_title_crew_df.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdb_title_principals_df = pd.read_csv('data/imdb.title.principals.csv.gz')

# %%
imdb_title_principals_df.head(20)
# imdb_title_principals_df.category.value_counts()
# Out:
#        tconst  ordering     nconst         category       job  \
# 0   tt0111414         1  nm0246005            actor       NaN
# 1   tt0111414         2  nm0398271         director       NaN
# 2   tt0111414         3  nm3739909         producer  producer
# 3   tt0323808        10  nm0059247           editor       NaN
# 4   tt0323808         1  nm3579312          actress       NaN
# 5   tt0323808         2  nm2694680            actor       NaN
# 6   tt0323808         3  nm0574615            actor       NaN
# 7   tt0323808         4  nm0502652          actress       NaN
# 8   tt0323808         5  nm0362736         director       NaN
# 9   tt0323808         6  nm0811056         producer  producer
# 10  tt0323808         7  nm0914939         producer  producer
# 11  tt0323808         8  nm0779346         composer       NaN
# 12  tt0323808         9  nm0676104  cinematographer       NaN
# 13  tt0417610        10  nm0284261         composer       NaN
# 14  tt0417610         1  nm0532721            actor       NaN
# 15  tt0417610         2  nm0330974          actress       NaN
# 16  tt0417610         3  nm0069209            actor       NaN
# 17  tt0417610         4  nm0679167          actress       NaN
# 18  tt0417610         5  nm1145057         director       NaN
# 19  tt0417610         6  nm0083201           writer     story
#
#                   characters
# 0                ["The Man"]
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4           ["Beth Boothby"]
# 5          ["Steve Thomson"]
# 6   ["Sir Lachlan Morrison"]
# 7    ["Lady Delia Morrison"]
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                 ["Lucio"]
# 15                 ["Diana"]
# 16         ["Dr. Samaniego"]
# 17         ["Adriana María"]
# 18                       NaN
# 19                       NaN

# %%
imdb_title_ratings_df = pd.read_csv('data/imdb.title.ratings.csv.gz')

# %%
imdb_title_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# rt_movie_info_df = pd.read_csv('data/rt.movie_info.tsv.gz')
# rt_movie_info_df.head()
# rt_reviews_df = pd.read_csv('data/rt.reviews.tsv.gz')
# rt_reviews_df.head()

# What is up with this .tsv type of file??

# %%
tmdb_movies_df = pd.read_csv('data/tmdb.movies.csv.gz')

# %%
tmdb_movies_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %% [markdown]
# # Summary of Step 1
#
# ## First Round of Questions About Data
#
# 1. Can we find out how these movies were released? as in on Netflix/Hulu/Box Office/Amazon Prime/YouTube?
# 2. How are movie genres determined?
# 3. How dirty are any of these data sets?
# 4. Do we know that grosses are USD?
# 5. And do dollars account for inflation?
# 6. How much rounding is going on in these grosses?
#
# ## Ideas About What We Can Ask
#
# 1. Can movies be very popular if they are released closely together? Maybe viewer fatigue is something to watch out for...
# 2. What is the difference between movies which do well both in the US and abroad, and movies which only do well in one or the other?
# 3. What is the minimum level of movie budget that correlated with different levels of US/Worldwide income?
# 4. **Of producers who are known for recently released movieswith no domestic grossn(streamed releases), who spends the most and has the highest ratings**

# %% [markdown]
# # Step 2: Let's try to clean some of this data
# ***

# %% [markdown]
# ## Clean with tn_movie_budgets_df

# %%
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.1+ KB

# %%
tn_movie_budgets_df.shape
# Out:
# (5782, 6)

# %% [markdown]
# ***
# ### Are any rows duplicated?
# ***

# %%
tn_movie_budgets_df.duplicated().sum()
# Out:
# 0

# %%
tn_movie_budgets_df.duplicated('movie').sum()
# Out:
# 84

# %%
tn_movie_budgets_df['repeated_name'] = tn_movie_budgets_df.movie.duplicated(keep=False)

# %%
tn_movie_budgets_df[tn_movie_budgets_df['repeated_name'] == True].sort_values('movie')
# Out:
#        id  release_date                         movie production_budget  \
# 4270   71  Dec 23, 1954  20,000 Leagues Under the Sea        $5,000,000
# 5614   15  Dec 24, 1916  20,000 Leagues Under the Sea          $200,000
# 1648   49  Apr 30, 2010     A Nightmare on Elm Street       $35,000,000
# 5016   17   Nov 9, 1984     A Nightmare on Elm Street        $1,800,000
# 2032   33  Nov 11, 1992                       Aladdin       $28,000,000
# 80     81  May 24, 2019                       Aladdin      $182,000,000
# 50     51   Mar 5, 2010           Alice in Wonderland      $200,000,000
# 4759   60  Jul 28, 1951           Alice in Wonderland        $3,000,000
# 4120   21  Oct 17, 1956   Around the World in 80 Days        $6,000,000
# 340    41  Jun 16, 2004   Around the World in 80 Days      $110,000,000
# 134    35  Mar 17, 2017          Beauty and the Beast      $160,000,000
# 2485   86  Nov 13, 1991          Beauty and the Beast       $20,000,000
# 3007    8  Nov 18, 1959                       Ben-Hur       $15,000,000
# 422    23  Aug 19, 2016                       Ben-Hur       $95,000,000
# 3307    8  Aug 14, 2015                      Brothers       $13,000,000
# 2140   41   Dec 4, 2009                      Brothers       $26,000,000
# 4058   59  Mar 26, 2010                          Ca$h        $7,000,000
# 3231   32  Dec 31, 2008                          Ca$h       $13,700,000
# 1925   26  Oct 18, 2013                        Carrie       $30,000,000
# 5015   16  Nov 16, 1976                        Carrie        $1,800,000
# 359    60  Nov 17, 2006                 Casino Royale      $102,000,000
# 3381   82  Apr 28, 1967                 Casino Royale       $12,000,000
# 3325   26   Apr 2, 1982                    Cat People       $12,500,000
# 5668   69  Nov 16, 1942                    Cat People          $134,000
# 4775   76  Feb 15, 1950                    Cinderella        $2,900,000
# 412    13  Mar 13, 2015                    Cinderella       $95,000,000
# 3050   51  Jun 12, 1981           Clash of the Titans       $15,000,000
# 271    72   Apr 1, 2010           Clash of the Titans      $125,000,000
# 475    76  Aug 19, 2011           Conan the Barbarian       $90,000,000
# 2543   44  May 14, 1982           Conan the Barbarian       $20,000,000
# ...   ...           ...                           ...               ...
# 1376   77  Jun 11, 2010                The Karate Kid       $40,000,000
# 3862   63  Jun 22, 1984                The Karate Kid        $8,000,000
# 3043   44  Mar 13, 2009    The Last House on the Left       $15,000,000
# 5699  100  Aug 30, 1972    The Last House on the Left           $87,000
# 5603    4  Aug 18, 2015               The Love Letter          $250,000
# 3109   10  May 21, 1999               The Love Letter       $15,000,000
# 64     65   Jun 9, 2017                     The Mummy      $195,000,000
# 543    44   May 7, 1999                     The Mummy       $80,000,000
# 2189   90   Jun 6, 2006                      The Omen       $25,000,000
# 4784   85  Jun 25, 1976                      The Omen        $2,800,000
# 5718   19  Feb 22, 2008                    The Signal           $50,000
# 4525   26  Jun 13, 2014                    The Signal        $4,000,000
# 5099  100  Oct 25, 2013                    The Square        $1,500,000
# 5009   10   Apr 9, 2010                    The Square        $1,900,000
# 3233   34   Oct 5, 1956          The Ten Commandments       $13,500,000
# 3694   95  Oct 19, 2007          The Ten Commandments       $10,000,000
# 3768   69  Oct 17, 2003   The Texas Chainsaw Massacre        $9,000,000
# 5665   66  Oct 18, 1974   The Texas Chainsaw Massacre          $140,000
# 779    80   Jun 1, 1990                  Total Recall       $65,000,000
# 278    79   Aug 3, 2012                  Total Recall      $125,000,000
# 5330   31  Dec 31, 2012                        Trance          $950,000
# 2970   71   Apr 5, 2013                        Trance       $16,000,000
# 2619   20   Mar 6, 1998                      Twilight       $20,000,000
# 1588   89  Nov 21, 2008                      Twilight       $37,000,000
# 2838   39  Feb 23, 1996                 Unforgettable       $18,000,000
# 3403    4  Apr 21, 2017                 Unforgettable       $12,000,000
# 1420   21  Feb 18, 2011                       Unknown       $40,000,000
# 4583   84   Nov 3, 2006                       Unknown        $3,700,000
# 2313   14  Sep 16, 2005                         Venom       $25,000,000
# 302     3   Oct 5, 2018                         Venom      $116,000,000
#
#      domestic_gross worldwide_gross  repeated_name
# 4270    $28,200,000     $28,200,000           True
# 5614     $8,000,000      $8,000,000           True
# 1648    $63,075,011    $117,729,621           True
# 5016    $25,504,513     $25,504,513           True
# 2032   $217,350,219    $504,050,219           True
# 80     $246,734,314    $619,234,314           True
# 50     $334,191,110  $1,025,491,110           True
# 4759             $0              $0           True
# 4120    $42,000,000     $42,000,000           True
# 340     $24,004,159     $72,004,159           True
# 134    $504,014,165  $1,259,199,706           True
# 2485   $376,057,266    $608,431,132           True
# 3007    $73,000,000     $73,259,017           True
# 422     $26,410,477     $91,669,648           True
# 3307       $656,688     $17,856,688           True
# 2140    $28,544,157     $45,043,870           True
# 4058        $46,488         $46,488           True
# 3231             $0     $11,738,256           True
# 1925    $35,266,619     $82,409,520           True
# 5015    $25,878,153     $25,878,153           True
# 359    $167,365,000    $594,420,283           True
# 3381    $22,744,718     $41,744,718           True
# 3325     $7,000,000     $21,000,000           True
# 5668     $4,000,000      $8,000,000           True
# 4775    $85,000,000    $263,591,415           True
# 412    $201,151,353    $534,551,353           True
# 3050    $30,000,000     $44,400,000           True
# 271    $163,214,888    $493,214,888           True
# 475     $21,295,021     $63,356,133           True
# 2543    $38,264,085     $79,114,085           True
# ...             ...             ...            ...
# 1376   $176,591,618    $351,774,938           True
# 3862    $90,815,558     $90,815,558           True
# 3043    $32,752,215     $46,526,243           True
# 5699     $3,100,000      $3,100,000           True
# 5603             $0              $0           True
# 3109     $8,322,608      $9,010,980           True
# 64      $80,101,125    $409,953,905           True
# 543    $155,385,488    $416,385,488           True
# 2189    $54,607,383    $119,295,584           True
# 4784    $48,570,885     $48,570,885           True
# 5718       $251,150        $406,299           True
# 4525       $600,896      $2,665,322           True
# 5099       $124,244        $176,262           True
# 5009       $406,216        $740,932           True
# 3233    $85,400,591     $85,434,516           True
# 3694       $952,820      $1,051,907           True
# 3768    $80,571,655    $107,967,319           True
# 5665    $26,572,439     $26,572,439           True
# 779    $119,394,839    $261,400,000           True
# 278     $58,877,969    $211,856,088           True
# 5330             $0              $0           True
# 2970     $2,322,593     $22,594,052           True
# 2619    $15,055,091     $15,055,091           True
# 1588   $192,769,854    $402,280,159           True
# 2838     $2,483,790      $2,483,790           True
# 3403    $11,368,012     $16,221,211           True
# 1420    $63,686,397    $136,123,083           True
# 4583        $26,403      $3,355,048           True
# 2313       $881,745        $881,745           True
# 302    $213,511,408    $853,628,605           True
#
# [165 rows x 7 columns]

# %% [markdown]
# There appear to be no actually duplicated data, all of the duplicated rows appear to be remakes of an original. Lets change the name of that column from ```repeated_name``` to ```remade```.

# %%
tn_movie_budgets_df['repeated_name'] = tn_movie_budgets_df.movie.duplicated()

# %%
tn_movie_budgets_df.rename(columns={'repeated_name':'remade'}, inplace=True)

# %% [markdown]
# No, there aren't duplicated rows in a negative sense.
# Just remade movies.
# We're okay with that!

# %% [markdown]
# ***
# ### Are their weird values?
# ***
#
# While checking for duplicates, we noticed that there were 0s in the ```domestic_gross``` and ```worldwide_gross``` columns.
# Lets do the following:
# - [ ] first, convert all money columns to ints from objects,
# - [ ] second, make a new column called ```international_gross``` which is ```worldwide_gross```$-$```domestic_gross```, and
# - [ ] finally, decide whether or not to drop rows with too many \$0s.
# ***

# %%
tn_movie_budgets_df.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# remade                 bool
# dtype: object

# %%
tn_movie_budgets_df = tn_movie_budgets_df.astype({'production_budget':'str', 'domestic_gross':'str', 'worldwide_gross':'str'})

# %% [markdown]
# The following 5 cells should be rolled into one function called convert_money_obj_to_int

# %%
def get_rid_of_dollar_sign(amount):
    if amount.startswith('$'):
        amount = amount[1:]
    else:
        print('Crap, one of my values didn\'t start with a dollar sign')
    return amount

# %%
for title in ['production_budget', 'domestic_gross', 'worldwide_gross']:
    tn_movie_budgets_df[title] = tn_movie_budgets_df[title].map(get_rid_of_dollar_sign)

# %%
for title in ['production_budget', 'domestic_gross', 'worldwide_gross']:
    tn_movie_budgets_df[title] = tn_movie_budgets_df[title].map(lambda x: x.replace(',','_'))

# %%
tn_movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross  remade
# 0       425_000_000    760_507_625   2_776_345_279   False
# 1       410_600_000    241_063_875   1_045_663_875   False
# 2       350_000_000     42_762_350     149_762_350   False
# 3       330_600_000    459_005_868   1_403_013_963   False
# 4       317_000_000    620_181_382   1_316_721_747   False

# %%
tn_movie_budgets_df = tn_movie_budgets_df.astype({'production_budget':'int64', 'domestic_gross':'int64', 'worldwide_gross':'int64'})

# %%
tn_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null int64
# domestic_gross       5782 non-null int64
# worldwide_gross      5782 non-null int64
# remade               5782 non-null bool
# dtypes: bool(1), int64(4), object(2)
# memory usage: 276.8+ KB

# %% [markdown]
# ***
# - [x] first, convert all money columns to ints from objects,
# - [ ] second, make a new column called ```international_gross``` which is ```worldwide_gross```$-$```domestic_gross```, and
# - [ ] finally, decide whether or not to drop rows with too many \$0s.
# ***
#
# While we're at it, we might as well make all the columns the appropriate data types...

# %%
tn_movie_budgets_df = tn_movie_budgets_df.astype({'movie':'str'})

# %%
tn_movie_budgets_df.release_date = pd.to_datetime(tn_movie_budgets_df.release_date)

# %%
tn_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
# id                   5782 non-null int64
# release_date         5782 non-null datetime64[ns]
# movie                5782 non-null object
# production_budget    5782 non-null int64
# domestic_gross       5782 non-null int64
# worldwide_gross      5782 non-null int64
# remade               5782 non-null bool
# dtypes: bool(1), datetime64[ns](1), int64(4), object(1)
# memory usage: 276.8+ KB

# %% [markdown]
# ...Okay, back to the business at hand.

# %%
tn_movie_budgets_df['international_gross'] = tn_movie_budgets_df['worldwide_gross'] - tn_movie_budgets_df['domestic_gross']

# %% [markdown]
# - [x] first, onvert all money columns to ints from objects,
# - [x] second, make a new column called ```international_gross``` which is ```worldwide_gross```$-$```domestic_gross```, and
# - [ ] finally, decide whether or not to drop rows with too many \$0s.

# %%
tn_movie_budgets_df.loc[tn_movie_budgets_df.international_gross == 0].shape
# Out:
# (1619, 8)

# %% [markdown]
# ***
# Thats a lot of movies with no international gross!
#
# Now I'm concerned about movies with no worldwide gross or no domestic gross.
# Lets see how many of those there are.
# ***

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.domestic_gross) == 0].shape
# Out:
# (548, 8)

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.domestic_gross) == 0].head()

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.worldwide_gross | tn_movie_budgets_df.domestic_gross) == 0].shape
# Out:
# (367, 8)

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.worldwide_gross | tn_movie_budgets_df.domestic_gross) == 0].head()

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.domestic_gross) == 0].loc[(tn_movie_budgets_df.worldwide_gross) > 0].shape
# Out:
# (181, 8)

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.domestic_gross) == 0].loc[(tn_movie_budgets_df.worldwide_gross) > 0].head()

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.worldwide_gross) == 0].shape
# Out:
# (367, 8)

# %%
tn_movie_budgets_df.loc[(tn_movie_budgets_df.worldwide_gross) == 0].head()
# Out:
#      id release_date             movie  production_budget  domestic_gross  \
# 194  95   2020-12-31          Moonfall          150000000               0
# 479  80   2017-12-13            Bright           90000000               0
# 480  81   2019-12-31  Army of the Dead           90000000               0
# 535  36   2020-02-21  Call of the Wild           82000000               0
# 670  71   2019-08-30         PLAYMOBIL           75000000               0
#
#      worldwide_gross  remade  international_gross
# 194                0   False                    0
# 479                0   False                    0
# 480                0   False                    0
# 535                0   False                    0
# 670                0   False                    0

# %% [markdown]
# There are 548 movies with 0 dollars in ```domestic_gross```.
# Of those movies, 181 have ```international_gross``` (maybe were only released internationally), and the other 367 have no ```domestic_gross``` or ```international_gross```.
# We think these 367 movies were released online only, which means they are of particular interest to our analysis!
# ***
# So we are deciding to keep all of our data:
# - [x] first, onvert all money columns to ints from objects,
# - [x] second, make a new column called ```international_gross``` which is ```worldwide_gross```$-$```domestic_gross```, and
# - [x] finally, decide whether or not to drop rows with too many \$0s.
#
#
# We are also deciding to compare the set of data we think are online releases to the data we think are not.
# Let's create a new column to mark their differences, then continue cleaning the data by isolating the released between 2010 and 2018.

# %%
tn_movie_budgets_df['online_release'] = tn_movie_budgets_df.worldwide_gross.map(lambda x: x==0)

# %% [markdown]
# ### Get rid of movies not released between 2010 and 2018

# %%
tn_movie_budgets_df['release_year'] = tn_movie_budgets_df.release_date.map(lambda x: x.year)

# %%
recent_tn_movie_budgets_df = tn_movie_budgets_df.loc[(2010<=tn_movie_budgets_df['release_year']) & (tn_movie_budgets_df['release_year']<=2018)]

# %%
recent_tn_movie_budgets_df.online_release.value_counts()
# Out:
# False    1873
# True      251
# Name: online_release, dtype: int64

# %% [markdown]
# There are still 251 online releases and 1873 box office releases; enough to perform some analysis.

# %% [markdown]
# # Step 3: Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot('release_date', 'production_budget', data=recent_tn_movie_budgets_df.loc[recent_tn_movie_budgets_df['online_release']==True], fit_reg=False)

# %%
sns.lmplot('release_date', 'production_budget', data=recent_tn_movie_budgets_df.loc[recent_tn_movie_budgets_df['online_release']==False], fit_reg=False)

# %%
sns.lmplot('production_budget', 'worldwide_gross', data=recent_tn_movie_budgets_df.loc[recent_tn_movie_budgets_df['online_release']==False], fit_reg=False)

# %%
sns.lmplot('production_budget', 'domestic_gross', data=recent_tn_movie_budgets_df.loc[recent_tn_movie_budgets_df['online_release']==False], fit_reg=False)

# %%
sns.lmplot('production_budget', 'international_gross', data=recent_tn_movie_budgets_df.loc[recent_tn_movie_budgets_df['online_release']==False], fit_reg=False)

# %% [markdown]
# ## Next Ideas
#
# Can we guess how much the online releases made based on the data from the box office releases?
# To do that, we could:
# 1. Find (linear) regression between production value and different grosses
# 2. After merging data, find relationship between ratings and different grosses
# 3. If relationships are similar, use ratings as a proxy for gross in online release data
# 4. Estimate the return on production value for online releases
