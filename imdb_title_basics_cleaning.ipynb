# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
imdb_title_basics = pd.read_csv('data/imdb.title.basics.csv.gz')
imdb_title_basics = imdb_title_basics.loc[imdb_title_basics['start_year'] < 2019] # restrict movies between 2010-2018
imdb_title_basics.head(7)
# Out:
#       tconst               primary_title              original_title  \
# 0  tt0063540                   Sunghursh                   Sunghursh
# 2  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204             Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275    The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                 A Thin Life                 A Thin Life
# 6  tt0112502                     Bigfoot                     Bigfoot
# 7  tt0137204             Joe Finds Grace             Joe Finds Grace
#
#    start_year  runtime_minutes                      genres
# 0        2013            175.0          Action,Crime,Drama
# 2        2018            122.0                       Drama
# 3        2018              NaN                Comedy,Drama
# 4        2017             80.0        Comedy,Drama,Fantasy
# 5        2018             75.0                      Comedy
# 6        2017              NaN             Horror,Thriller
# 7        2017             83.0  Adventure,Animation,Comedy

# %%
imdb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136702 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             136702 non-null object
# primary_title      136702 non-null object
# original_title     136683 non-null object
# start_year         136702 non-null int64
# runtime_minutes    109815 non-null float64
# genres             131664 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.3+ MB

# %%
imdb_gen_expand = imdb_title_basics.genres.str.split(",", expand=True)

# %%
imdb_title_basics['genres_1']=imdb_gen_expand[0]
imdb_title_basics['genres_2']=imdb_gen_expand[1]
imdb_title_basics['genres_3']=imdb_gen_expand[2]
#imdb_title_basics.drop('genres', axis=1, inplace=True)

# %%
imdb_title_basics.head()
# Out:
#       tconst               primary_title              original_title  \
# 0  tt0063540                   Sunghursh                   Sunghursh
# 2  tt0069049  The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204             Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275    The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                 A Thin Life                 A Thin Life
#
#    start_year  runtime_minutes                genres genres_1 genres_2  \
# 0        2013            175.0    Action,Crime,Drama   Action    Crime
# 2        2018            122.0                 Drama    Drama     None
# 3        2018              NaN          Comedy,Drama   Comedy    Drama
# 4        2017             80.0  Comedy,Drama,Fantasy   Comedy    Drama
# 5        2018             75.0                Comedy   Comedy     None
#
#   genres_3
# 0    Drama
# 2     None
# 3     None
# 4  Fantasy
# 5     None

# %%
imdb_title_basics.set_index('tconst', inplace=True)

# %%
imdb_title_basics
# Out:
#                                                primary_title  \
# tconst
# tt0063540                                          Sunghursh
# tt0069049                         The Other Side of the Wind
# tt0069204                                    Sabse Bada Sukh
# tt0100275                           The Wandering Soap Opera
# tt0111414                                        A Thin Life
# tt0112502                                            Bigfoot
# tt0137204                                    Joe Finds Grace
# tt0139613                                         O Silêncio
# tt0144449                              Nema aviona za Zagreb
# tt0146592                                        Pál Adrienn
# tt0154039                               So Much for Justice!
# tt0159369                 Cooper and Hemingway: The True Gen
# tt0162942                       Children of the Green Dragon
# tt0170651                               T.G.M. - osvoboditel
# tt0176694                                 The Tragedy of Man
# tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# tt0192528                                      Heaven & Hell
# tt0230212                                  The Final Journey
# tt9910688         None      None
# tt9910922          NaN       NaN
# tt9913594      Mystery  Thriller
# tt9914642         None      None
# tt9914644         None      None
# tt9914662         None      None
# tt9914828       Comedy    Family
# tt9916132  Documentary   History
# tt9916186         None      None
# tt9916622         None      None
# tt9916706         None      None
# tt9916730          NaN       NaN
# tt9916754         None      None
#
# [136702 rows x 8 columns]

# %%
imdb_names = pd.read_csv('data/imdb_names_update')
imdb_names.rename(columns={'movie_titles': 'tconst'}, inplace=True)
imdb_names.set_index('tconst', inplace=True)
imdb_names.drop('Unnamed: 0', axis=1, inplace=True)

# %%
imdb_names.head()
# Out:
#                 primary_name     nconst  \
# tconst
# tt0837562  Mary Ellen Bauder  nm0061671
# tt0896534       Joseph Bauer  nm0061865
# tt1470654         Bruce Baum  nm0062070
# tt0114371       Axel Baumann  nm0062195
# tt0452644        Pete Baxter  nm0062798
#
#                                          primary_profession
# tconst
# tt0837562         miscellaneous,production_manager,producer
# tt0896534        composer,music_department,sound_department
# tt1470654                        miscellaneous,actor,writer
# tt0114371  camera_department,cinematographer,art_department
# tt0452644  production_designer,art_department,set_decorator

# %% [markdown]
# ### Join IMDB_titles and IMDB_names dataframes

# %%
imdb_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1580490 entries, tt0837562 to tt4921464
# Data columns (total 3 columns):
# primary_name          1580490 non-null object
# nconst                1580490 non-null object
# primary_profession    1580490 non-null object
# dtypes: object(3)
# memory usage: 48.2+ MB

# %%
imdb_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136702 entries, tt0063540 to tt9916754
# Data columns (total 8 columns):
# primary_title      136702 non-null object
# original_title     136683 non-null object
# start_year         136702 non-null int64
# runtime_minutes    109815 non-null float64
# genres             131664 non-null object
# genres_1           131664 non-null object
# genres_2           56456 non-null object
# genres_3           28070 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 9.4+ MB

# %%
imdb_title_names = imdb_title_basics.join(imdb_names, 
                       how='inner')

# %%
imdb_title_names.head()
# Out:
#                         primary_title              original_title  start_year  \
# tconst
# tt0063540                   Sunghursh                   Sunghursh        2013
# tt0063540                   Sunghursh                   Sunghursh        2013
# tt0069049  The Other Side of the Wind  The Other Side of the Wind        2018
# tt0069049  The Other Side of the Wind  The Other Side of the Wind        2018
# tt0069049  The Other Side of the Wind  The Other Side of the Wind        2018
#
#            runtime_minutes              genres genres_1 genres_2 genres_3  \
# tconst
# tt0063540            175.0  Action,Crime,Drama   Action    Crime    Drama
# tt0063540            175.0  Action,Crime,Drama   Action    Crime    Drama
# tt0069049            122.0               Drama    Drama     None     None
# tt0069049            122.0               Drama    Drama     None     None
# tt0069049            122.0               Drama    Drama     None     None
#
#              primary_name     nconst                 primary_profession
# tconst
# tt0063540  Mahasweta Devi  nm1194313                             writer
# tt0063540   Anjana Rawail  nm1391276            writer,costume_designer
# tt0069049       Oja Kodar  nm0462648            actress,writer,director
# tt0069049    Tom Callaway  nm1152466  cinematographer,camera_department
# tt0069049      Dax Phelan  nm3902034           writer,producer,director
